# %% [markdown]
# # Tutorial

# %%
import sys
from pathlib import Path
import requests
import json
from dotenv import load_dotenv
import os

# Add project root to path
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from app.helper.pdf_processor import *
from app.helper.classifer import *

load_dotenv("../.env")
token = os.getenv("API_SECRET_TOKEN")
ip_aws = os.getenv("IP_AWS")
ip_local = os.getenv("IP_LOCAL")

# %% [markdown]
# ## Process original pdf file

# %% [markdown]
# ### Handbook

# %%
process_all_handbooks(levels = "pgr")
# Out:
# === Processing PGR handbook ===
# Extracting text from: /Users/qianhuilin/Desktop/AI_assistant/data/original_pdf/handbook-PGR.pdf
# Extracted 140182 characters of text.
# Saved extracted text locally to: /Users/qianhuilin/Desktop/AI_assistant/data/extracted/handbook-PGR.txt
# Uploaded extracted text to s3://original-text-bucket/handbook/handbook-pgr.txt

# %% [markdown]
# ### Academic Integrity Regulation

# %%
process_other_document(type="academic-integrity")
# Out:
# === Processing academic-integrity document ===
# Extracting text from: /Users/qianhuilin/Desktop/AI_assistant/data/original_pdf/academic-integrity.pdf
# Extracted 47863 characters of text.
# Saved extracted text locally to: /Users/qianhuilin/Desktop/AI_assistant/data/extracted/academic-integrity.txt
# Uploaded extracted text to s3://original-text-bucket/academic/academic-integrity.txt

# %% [markdown]
# ## Ask

# %% [markdown]
# ### Health check

# %%
ip = ip_local if os.getenv("MODE") == "development" else ip_aws
print("Using IP:", ip)
BASE_URL = f"http://{ip}:8080"
response = requests.get(f"{BASE_URL}/health")
print("Health Check:", response.json())
# Out:
# Using IP: localhost
# Health Check: {'status': 'ok'}

# %% [markdown]
# ### Enter question

# %%
question_payload = {
    "question": "How long can I be registered for a PhD?",
    "level": "pgr",
    "origin": "international"
}

# %% [markdown]
# ### Classification

# %%
category = classify_category(question_payload["question"])
print("Classified Category:", category)
# Out:
# Classified Category: handbook

# %%
response = requests.post(
    f"{BASE_URL}/ask_{category}",
    json=question_payload,
    headers={"Authorization": f"Bearer {token}"}
)

print("Answer:", response.json()["answer"])
print("\nSources:", response.json()["context_used"])
print("\nCollection_used:",response.json()["collection_used"])
# Out:
# Answer: As an international student registered for a PhD, you have a minimum full-time registration period of 48 months and a maximum of 60 months. Any extension beyond the maximum period must be approved by Student and Programme Administration, based on evidence of your progress, and can go up to an absolute maximum of 84 months. If you are a part-time student, the minimum registration period is 48 months, with a maximum of 84 months as well. Extensions for part-time studies follow similar guidelines.
#
# Sources: ['rd appropriate for scholarly publication.\nINTEGRATED PHD PROGRAMMES\n5. A candidate shall register at the outset for a PhD with a minimum full-time registration\nperiod of forty-eight months and maximum of sixty months. Any extension of the maximum\nperiod must be approved by Student and Programme Administration after consideration of\nevidence of the student’s progress submitted by the department concerned, up to an\nabsolute maximum of eighty-four months.\n6. A candidate shall undertake taught courses specified by the department of registration.\nSuch courses shall normally be completed within twenty-four months of first registration\nand lead to the award of MRes.\n7. Re-registration for the second year of study shall be contingent upon the recommendation\nof the department. Such recommendation shall be contingent upon:\n(a) successful completion of the specified taught courses, normally above the level of\nthe minimum pass mark; and\n(b) confirmation that a suitable topic for research has been identified i.e. a topic for\nwhich the student is deemed eligible and for which the department can provide\nappropriate support and supervision.\n8. In the absence of such a recommendation, the candidate shall withdraw from the\nprogramme. Students may appeal against this decision under the procedures for Academic\nAppeals.\n9. To be eligible for confirmation of the PhD, normally after a minimum of twenty-four months\nfrom first registration, the candidate shall:\n(a) submit for assessment written work of which a proportion specified by the\ndepartment shall be of an appropriate standard; and\n(b) satisfy a departmental exam board that they are academically capable of\nsuccessfully completing a thesis.\n10. The board may recommend one of the following:\n(a) that the candidate is eligible for confirmation of their PhD status, subject to\nsubmission of a satisfactory proposal for the thesis; or\n(b) that the candidate be invited to re-submit elements of written work to satisfy the\nrequirement of (a) ab', ' one of the following:\n(c) that the candidate is eligible for their PhD registration to be confirmed, subject to\nsubmission of a satisfactory proposal for the thesis; or\n(d) that the candidate be invited to re-submit elements of coursework, to satisfy the\nrequirement of (i) above, with one further opportunity for the PhD registration to be\nconfirmed; or\n(e) that the candidate be invited to complete the requirements for examination for the\naward of MPhil.\nNote: in the event that the board recommends (e), the candidate shall be eligible to appeal.\n3. A candidate in respect of whom the board has recommended (d) above, shall submit to a\ndepartmental panel normally within six calendar months from the date of notification of (c),\na proposal for a thesis of up to 70,000 words. After consideration of the proposal, the panel\nmay recommend one of the following:\n(a) that the candidate’s registration for a PhD. be confirmed; or\n(b) that the candidate be invited to revise and re-submit the proposal with one further\nopportunity for the PhD to be confirmed; or\n(c) that the candidate be invited to complete the requirements for the award of MPhil.\nNote: in the event that the board recommends (c), the candidate shall be eligible to appeal.\n4. A candidate who has satisfied the requirements is required to submit a thesis of normally\nnot more than 70,000 words, within sixty calendar months of first registration for the PhD.\nThe dissertation shall be examined according to the normal regulations above. To be eligible\nVersion 1.1 35\nMARP 2025-26\nPostgraduate Research Regulations\nfor the award of the PhD, the thesis shall make an original contribution to knowledge and\ncontain material of a standard appropriate for scholarly publication.\nINTEGRATED PHD PROGRAMMES\n5. A candidate shall register at the outset for a PhD with a minimum full-time registration\nperiod of forty-eight months and maximum of sixty months. Any exten ...
#
# Collection_used: handbook_pgr

# %%
question_payload_2 = {
    "question": "How is plagiarism detected in theses?",
    "level": "pgr",
    "origin": "international"
}

# %%
category = classify_category(question_payload_2["question"])
print("Classified Category:", category)
# Out:
# Classified Category: academic_integrity

# %%
response = requests.post(
    f"{BASE_URL}/ask_{category}",
    json=question_payload_2,
    headers={"Authorization": f"Bearer {token}"}
)

print("Answer:", response.json()["answer"])
print("\nSources:", response.json()["context_used"])
print("\nCollection_used:",response.json()["collection_used"])
# Out:
# Answer: Plagiarism in theses is typically detected through a combination of the following methods:
#
# 1. **Plagiarism Detection Software**: Universities often use software tools such as Turnitin, iThenticate, or Grammarly to scan submissions for similarities with existing published works, online content, and other students' theses. These tools highlight matches and provide a similarity report.
#
# 2. **Manual Review by Examiners**: Examining committees or supervisors may read the theses carefully to identify any instances of plagiarism. They look for inconsistencies in writing style, sudden shifts in quality, or sections that do not align with the student's voice.
#
# 3. **Check for Citations and References**: Reviewers assess whether all sources are properly cited and whether the student is correctly attributing ideas and content that are not their own. A lack of citations or incorrect citation practices can indicate potential plagiarism.
#
# 4. **Historical Analysis of Student’s Work**: Examiners may compare the thesis with the student's previous submissions to identify any significant overlap or repeated ideas that weren't appropriately acknowledged.
#
# 5. **Viva Voce Examination**: During an oral defense of the thesis (viva), examiners may ask questions about the research and the thesis content. A student's inability to discuss certain sections or unfamiliarity with cited materials may raise concerns about authorship and originality.
#
# If any signs of academic malpractice, including plagiarism, are detected during these processes, it can lead to further investigation and potential consequences as per the University’s academic integrity regulations.
#
# Sources: ['s or others an unfair advantage with a view to\nVersion 1.1 3\nMARP 2025-26\nAcademic Integrity Regulations\nachieving a higher grade, mark or more favourable outcome than they would otherwise\nsecure. Any attempt to convey deceitfully the impression of acquired knowledge, skills,\nunderstanding, or credentials, shall represent a contravention of the regulations of the\nUniversity, and may constitute grounds for exclusion.\nAM 2.2 PLAGIARISM\nAM 2.2.1 Plagiarism is understood to include, in whatever format it is presented, including written\nwork, group work or oral presentations, the following:\n(a) the act of copying or paraphrasing from a source without appropriate\nacknowledgement (this includes quoting directly from another source with a\nreference but without quotation marks);\n(b) the submission of all or part of another student’s work, whether with or without\nthat student’s knowledge or consent;\n(c) the commissioning or use of work by the student which is not their own and\nrepresenting it as if it were;\n(d) the submission of all or part of work purchased or obtained from a commercial\nservice;\n(e) the submission of all or part of work created by another person, whether by\nanother member of the University or a person who is not a member of the\nUniversity;\n(f) inclusion of material derived through False Authorship (as defined in AM 2.3\nbelow);\n(g) reproduction of the same or almost identical own work, in full or in part, which\nhas previously been submitted for assessment. This does not include\nprogrammes of study where the student is permitted or required to develop\npreviously assessed work into a larger argument for the dissertation/thesis;\n(h) directly copying from model solutions/answers made available.\nAM 2.3 FALSE AUTHORSHIP\nAM 2.3.1 False Authorship is a form of plagiarism where the student has deliberately engaged\nwith a third party and/or software tool to complete an assessment, either in part or\nwhole. This engagement can be direct or through an intermediary. This m', 'represented by another before the\nboard. Boards of examiners have absolute discretion to take into account, in making\ntheir decisions, such evidence as they may consider relevant to a student’s academic\nperformance and to decide whether to call for further oral or written evidence. They\nmay also take into account, but shall not be bound by, the suggestions of the Standing\nAcademic Committee. In considering the suggestions of the Standing Academic\nCommittee, the decisions of boards of examiners shall be subject to ratification by the\nCommittee of the Senate.\nVersion 1.1 12\nMARP 2025-26\nAcademic Integrity Regulations\nAM 6 ACADEMIC INTEGRITY IN THE RESEARCH DEGREE\nAM 6.1 APPLICABILITY\nAM 6.1.1 For the degrees of:\n(a) DSc, DLitt, PhD (including by published work), DClinPsy, DMgt, EngD, MPhil, MD;\nand\n(b) for the degrees of MA, MSc, LLM, MMus if relating to a programme validated for\nsuch awards on the basis of research and titled ‘By Research’;\nthe definition of malpractice is as set out in section AM 1 above and includes: cheating in\nexaminations (if applicable); plagiarism in the thesis or dissertation (or equivalent)\n(including in published works if submitted as a part of an award); and fabrication of\nresults.\nAM 6.1.2 In addition, for the awards listed above, plagiarism shall be deemed to include\nunacknowledged or unattributed concepts, proposals, interpretations, methodologies,\nor conclusions, which take place beyond the verbatim reproduction of texts or material\nwithout explicit identification or the source of the reference.\nAM 6.1.3 Reference to ‘thesis’ or ‘dissertation’ in these regulations includes those\nformats/outputs, as defined in the Postgraduate Regulations, which are deemed to be\nequivalent to the traditional PhD format.\nAM 6.1.4 Academic malpractice suspected to have occurred in work submitted for the assessment\nof taught components of research programmes will be considered un ...
#
# Collection_used: academic-integrity

# %%
data = response.json()


print("\nHistory:")
print(json.dumps(data.get("history", []), indent=2, ensure_ascii=False))
# Out:
# History:
# [
#   {
#     "question": "How long can I be registered for a PhD?",
#     "answer": "As an international student registered for a PhD, you have a minimum full-time registration period of 48 months and a maximum of 60 months. Any extension beyond the maximum period must be approved by Student and Programme Administration, based on evidence of your progress, and can go up to an absolute maximum of 84 months. If you are a part-time student, the minimum registration period is 48 months, with a maximum of 84 months as well. Extensions for part-time studies follow similar guidelines."
#   },
#   {
#     "question": "How is plagiarism detected in theses?",
#     "answer": "Plagiarism in theses is typically detected through a combination of the following methods:\n\n1. **Plagiarism Detection Software**: Universities often use software tools such as Turnitin, iThenticate, or Grammarly to scan submissions for similarities with existing published works, online content, and other students' theses. These tools highlight matches and provide a similarity report.\n\n2. **Manual Review by Examiners**: Examining committees or supervisors may read the theses carefully to identify any instances of plagiarism. They look for inconsistencies in writing style, sudden shifts in quality, or sections that do not align with the student's voice.\n\n3. **Check for Citations and References**: Reviewers assess whether all sources are properly cited and whether the student is correctly attributing ideas and content that are not their own. A lack of citations or incorrect citation practices can indicate potential plagiarism.\n\n4. **Historical Analysis of Student’s Work**: Examiners may compare the thesis with the student's previous submissions to identify any significant overlap or repeated ideas that weren't appropriately acknowledged.\n\n5. **Viva Voce Examination**: During an oral defense of the thesis (viva), examiners may ask questions about the research and the thesis content. A student's inability to discuss certain sections or unfamiliarity with cited materials may raise concerns about authorship and originality.\n\nIf any signs of academic malpractice, including plagiarism, are detected during these processes, it can lead to further investigation and potential consequences as per the University’s academic integrity regulations."
#   }
# ]
