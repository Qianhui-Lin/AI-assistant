# %% [markdown]
# # Tutorial

# %% [markdown]
# ### Process original pdf file

# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path.cwd().parent
if project_root not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from app.helper.pdf_processor import *

# %%
process_and_upload_pdf()
# Out:
# Extracting text from: /Users/qianhuilin/Desktop/AI_assistant/data/original_pdf/PGR-Regs.pdf
# Extracted 140182 characters of text.
# Saved extracted text locally to: /Users/qianhuilin/Desktop/AI_assistant/data/extracted/handbook.txt
# Uploaded extracted text to s3://original-text-bucket/pgr_handbook/pgr_handbook.txt
# "MANUAL OF ACADEMIC REGULATIONS\nAND PROCEDURES 2025-26\nPOSTGRADUATE RESEARCH REGULATIONS\n(APPLICABLE FROM OCTOBER 2025)\nAcademic Quality, Standards and Conduct\nStudent and Education Services\nMARP 2025-26\nMARP 2025-26\nPostgraduate Research Regulations\nCONTENTS\nPR 1 RESEARCH AWARDS ....................................................................... 3\nPR 2 PHD REGULATIONS ......................................................................... 3\nPR 2.1 CRITERIA FOR THE AWARD ........................................................................................ 3\nPR 2.2 REGISTRATION PERIOD.............................................................................................. 4\nPR 2.3 SCHEDULE OF WORK ................................................................................................. 5\nPR 2.4 PROGRESSION REQUIREMENTS ................................................................................. 6\nPR 2.5 CONFIRMATION OF PHD STATUS ............................................................................... 7\nPR 2.6 SUBMISSION OF THESIS ............................................................................................. 9\nPR 2.7 FORMAT OF THESIS ................................................................................................. 10\nPR 2.8 EXAMINATION ........................................................................................................ 10\nPR 2.9 EXAMINATION OUTCOMES ..................................................................................... 11\nPR 2.10 DISAGREEMENT BETWEEN EXAMINERS ON FIRST SUBMISSION OF THESIS ................ 12\nPR 2.11 RESUBMISSION ....................................................................................................... 13\nPR 2.12 DISAGREEMENT BETWEEN EXAMINERS UPON THESIS RESUBMITTED ....................... 14\nPR 3 MPHIL REGULATIONS ................................................................... 14\nPR 3.1 CRITERIA FOR THE AWARD ...................................................................................... 14\nPR 3.2 REGISTRATION PERIOD............................................................................................ 15\nPR 3.3 SCHEDULE OF WORK ............................................................................................... 15\nPR 3.4 PROGRESSION REQUIREMENTS ............................................................................... 16\nPR 3.5 SUBMISSION OF THESIS ........................................................................................... 16\nPR 3.6 FORMAT OF THESIS ................................................................................................. 17\nPR 3.7 EXAMINATION ........................................................................................................ 18\nPR 3.8 EXAMINATION OUTCOMES ..................................................................................... 18\nPR 3.9 DISAGREEMENT BETWEEN EXAMINERS ON FIRST SUBMISSION OF THESIS ................ 19\nPR 3.10 RESUBMISSION ....................................................................................................... 20\nPR 3.11 DISAGREEMENT BETWEEN EXAMINERS UPON THESIS RESUBMITTED ....................... 20\nPR 3.12 TRANSFER OF REGISTRATION FROM MPHIL TO PHD ................................................. 20\nPR 4 LLM/MA/MSC BY RESEARCH REGULATIONS ................................. 21\nPR 4.1 CRITERIA FOR THE AWARD ...................................................................................... 21\nPR 4.2 REGISTRATION PERIOD............................................................................................ 22\nPR 4.3 SUBMISSION OF DISSERTATION ............................................................................... 23\nPR 4.4 CONSIDERATION OF RESULTS BY BOARDS OF EXAMINATION ................................... 23\nVersion 1.1 1\nMARP 2025-26\nPostgraduate Research Regulations\nPR 5 APPOINTMENT OF EXAMINERS (ALL ...

# %%
import requests
import json
from dotenv import load_dotenv
import os

# %%
BASE_URL = "http://localhost:8080"
response = requests.get(f"{BASE_URL}/health")
print("Health Check:", response.json())
# Out:
# Health Check: {'status': 'ok'}

# %%
question_payload = {
    "question": "What is the vacation policy?"
}

# %%
load_dotenv("../.env")
token = os.getenv("API_SECRET_TOKEN")

# %%
response = requests.post(
    f"{BASE_URL}/feature",
    json=question_payload,
    headers={"Authorization": f"Bearer {token}"}
)

print("Answer:", response.json()["answer"])
print("\nSources:", response.json()["context_used"])
# Out:
# Answer: The vacation policy typically allows students to take breaks from their studies during designated periods, but specific details may vary between programs and departments. Generally, postgraduate research students are encouraged to discuss any planned vacations with their supervisor to ensure that it does not interfere with their research progress. Students should also consider the academic calendar when planning their vacations to align with university-recommended breaks.
#
# For the most accurate and detailed information, including how vacation days are calculated and any specific restrictions, students should refer to their program handbook or consult directly with their department or faculty administration.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 8
#       1 response = requests.post(
#       2     f"{BASE_URL}/feature",
#       3     json=question_payload,
#       4     headers={"Authorization": f"Bearer {token}"}
#       5 )
#       7 print("Answer:", response.json()["answer"])
# ----> 8 print("\nSources:", response.json()["sources"])
#
# KeyError: 'sources'
